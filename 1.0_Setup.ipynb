# %% [markdown]
# # Prediction of Product Sales

# %% [markdown]
# - Author: Salam Odeh
#
# ## Project Overview
#
# This is a Data Science portfolio project completed as part of the AXSOS Academy Introduction to Machine Learning course.
#
# **Goal:** Help a retailer understand the properties of products and outlets (stores) that play crucial roles in increasing sales, and build a machine learning model to predict `Item_Outlet_Sales` for products at various outlets.
#
# **Dataset:** [Sales Pridiction ](https://drive.google.com/file/d/1syH81TVrbBsdymLT_jl2JIf6IjPXtSQw/view) - contains 8,523 rows and 12 columns describing products, outlets, and historical sales.
#
# This notebook (Part 1) sets up the project structure. Each subsequent part of the project will build on this, following the CRISP-DM process:
# 1. Business Understanding
# 2. Data Understanding
# 3. Data Preparation
# 4. Modeling
# 5. Evaluation
# 6. Deployment

# %% [markdown]
# ## Load and Inspect Data

# %%
# This section will be completed in Part 2 (Core)
# - Load the data with Pandas
# - Inspect rows/columns, datatypes, duplicates, missing values, summary stats

# %% [markdown]
# ## Clean Data

# %%
# This section will be completed in Part 2 (Core)
# - Drop duplicates
# - Address missing values with a placeholder
# - Fix inconsistent categories

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# This section will be completed in Part 3 (Core)
# - Histograms, boxplots, countplots, and a correlation heatmap

# %% [markdown]
# ## Feature Inspection

# %%
# This section will be completed in Part 4 (Core)
# - Inspect each feature: type, nulls, cardinality, constant/quasi-constant,
#   whether known before target, business case to exclude
# - Univariate and multivariate (feature vs. target) visuals

# %% [markdown]
# ## Preprocessing

# %%
# This section will be completed in Part 5 (Core)
# - Reload fresh/uncleaned data to avoid data leakage
# - Define X (features) and y (target = Item_Outlet_Sales)
# - Train/test split
# - Build preprocessing object (ColumnTransformer with imputation,
#   scaling, and encoding) - fit only on training data

# %% [markdown]
# ## Modeling

# %%
# This section will be completed in Part 6 (Core)
# - Linear Regression model + evaluation
# - Default Random Forest model + evaluation
# - GridSearchCV tuning of Random Forest + evaluation
# - Model comparison and final recommendation
