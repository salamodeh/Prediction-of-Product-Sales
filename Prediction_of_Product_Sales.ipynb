# %% [markdown]
# <a href="https://colab.research.google.com/github/salamodeh/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#   File "/tmp/ipykernel_3141/140348161.py", line 3
#     This notebook analyzes sales data using Pandas.
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Prediction of Product Sales
# - Auther: Salam Odeh
#
#
# ## Project Overview
# In [ ]:
#
# ## Load and Inspect Data
# In [ ]:
#
# ## Clean Data
# In [ ]:
#
# ## Exploratory Data Analysis
# In [ ]:
#
# ## Feature Inspection
# In [ ]:
